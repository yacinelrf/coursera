# %%
# Mon Carnet Jupyter pour la Science des Données

# %%
## Introduction
Ce carnet présente un aperçu des outils, langages et bibliothèques utilisés en science des données.

# %%
## Langages de la science des données
- Python
- R
- SQL
- Scala

# %%
## Bibliothèques de science des données
- Pandas
- NumPy
- Matplotlib
- Seaborn
- SciPy
- Scikit-learn

# %%
## Tableau des outils de la science des données

| Outil          | Usage principal                        |
|----------------|----------------------------------------|
| Jupyter Notebook | Création et partage de notebooks      |
| RStudio         | Analyse statistique et visualisation   |
| GitHub          | Contrôle de version et collaboration   |
| Anaconda        | Gestion d'environnements et paquets    |
| Watson Studio   | Développement de projets IA            |

# %%
## Exemples d'expressions arithmétiques
- Addition : 5 + 3
- Soustraction : 10 - 2
- Multiplication : 4 * 6
- Division : 12 / 3

# %%
# Multiplication et addition
a = 5
b = 3
c = 2

resultat = a * b + c
resultat

# %%
# Conversion de minutes en heures
minutes = 150
heures = minutes / 60
heures

# %%
## Objectifs
- Comprendre les langages utilisés en science des données
- Identifier les principales bibliothèques et outils
- Apprendre à utiliser Jupyter Notebook pour créer et partager des analyses

# %%
## Auteur
Yacine Larfi
